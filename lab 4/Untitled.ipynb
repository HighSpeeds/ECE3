# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_data=np.array([10,
26,
9,
20,
51,
19,
30,
77,
30,
40,
102,
41,
50,
128,
52,
60,
153,
62,
70,
179,
71,
80,
204,
77,
90,
230,
81,
100,
255,
84])
data=raw_data.reshape([10,3])

bin_len=50*10**-3

# %%
plt.plot(data[:,0],data[:,2]/bin_len)
plt.xlabel("Duty Cycle")
plt.ylabel("Encoder Counts per Second")
plt.savefig("fig1.png")
