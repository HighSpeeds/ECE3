# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
df=pd.read_excel("data.xlsx")

# %%
basic_pid=df.iloc[3:11,:4]
basic_pid
# Out:
#    2022-05-20 00:00:00 Unnamed: 1        Unnamed: 2          Unnamed: 3
# 3                  k_p        k_D  Oscillations (5)  Acceptability (10)
# 4                 0.25          0                 0                   1
# 5                    1          0                 1                   2
# 6                    5          0                 4                   4
# 7                    5          1                 2                   7
# 8                    5        1.5                 1                   4
# 9                    8        1.5                 1                   8
# 10                   8       1.15                 2                   9

# %%
basic_pid.columns=basic_pid.iloc[0].to_list()
basic_pid=basic_pid.iloc[1:]
basic_pid
# Out:
#      k_p   k_D Oscillations (5) Acceptability (10)
# 4   0.25     0                0                  1
# 5      1     0                1                  2
# 6      5     0                4                  4
# 7      5     1                2                  7
# 8      5   1.5                1                  4
# 9      8   1.5                1                  8
# 10     8  1.15                2                  9

# %%
colors = cm.rainbow
for i in range(len(basic_pid)):
    plt.plot(basic_pid['k_p'].iloc[i],basic_pid['k_D'].iloc[i], "o",color=plt.get_cmap("RdYlGn")(basic_pid["Acceptability (10)"].iloc[i]*50))
plt.xlabel('k_p')
plt.ylabel('k_i')
# Out:
# Text(0, 0.5, 'k_i')

# %%
fig,axs=plt.subplots(1,2,figsize=(10,5))
plt.sca(axs[0])

cm=plt.get_cmap("cool_r")
pos=plt.scatter(basic_pid['k_p'],basic_pid['k_D'],c=basic_pid["Oscillations (5)"].astype(int), 
            vmin=0, vmax=max(basic_pid["Oscillations (5)"]), s=35, cmap=cm)

plt.xlabel('k_p')
plt.ylabel('k_i')
plt.title("Oscilations")
fig.colorbar(pos, ax=axs[0])
plt.sca(axs[1])
cm=plt.get_cmap("cool")

pos=plt.scatter(basic_pid['k_p'],basic_pid['k_D'],c=basic_pid["Acceptability (10)"].astype(int), 
            vmin=0, vmax=max(basic_pid["Acceptability (10)"]), s=35, cmap=cm)
plt.xlabel('k_p')
plt.ylabel('k_i')
plt.title("Acceptability")
fig.colorbar(pos, ax=axs[1])
fig.suptitle("Basic PID Visulaization")
plt.savefig("basic_pidPlots.png")

# %%
df.iloc[:,0]
# Out:
# 0     Today we finished the basic PID code entirely ...
# 1     To begin, we're going to try a slow speed of 5...
# 2                                                   NaN
# 3                                                   k_p
# 4                                                  0.25
#                             ...
# 85                                                   18
# 86                                                   18
# 87                                                   18
# 88                                                  NaN
# 89    We noticed the car was not consistently making...
# Name: 2022-05-20 00:00:00, Length: 90, dtype: object

# %%
cm(basic_pid["Acceptability (10)"].astype(float)*50)
# Out:
# array([[0.        , 0.40784314, 0.21568627, 1.        ],
#        [0.        , 0.40784314, 0.21568627, 1.        ],
#        [0.        , 0.40784314, 0.21568627, 1.        ],
#        [0.        , 0.40784314, 0.21568627, 1.        ],
#        [0.        , 0.40784314, 0.21568627, 1.        ],
#        [0.        , 0.40784314, 0.21568627, 1.        ],
#        [0.        , 0.40784314, 0.21568627, 1.        ]])

# %%
int("a")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_19345/3221825202.py in <module>
# ----> 1 int("a")
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
pd.read_csv("Data - Sheet1.csv")
# Out:
#       k_p   k_D  Oscillations  Acceptability  Velocity  Time  Voltage  \
# 0    0.25  0.00             0              1        50   NaN      NaN
# 1    1.00  0.00             1              2        50   NaN      NaN
# 2    5.00  0.00             4              4        50   NaN      NaN
# 3    5.00  1.00             2              7        50   NaN      NaN
# 4    5.00  1.50             1              4        50   NaN      NaN
# 5    8.00  1.50             1              8        50   NaN      NaN
# 6    8.00  1.15             2              9        50   NaN      NaN
# 7    8.00  1.15             3              5       100   NaN      NaN
# 8   10.00  1.15             5              4       100   NaN      NaN
# 9   10.00  1.50             3              6       100   NaN      NaN
# 10  12.00  1.50             4              5       100   NaN      NaN
# 11  12.00  1.75             2              7       100   NaN      NaN
# 12  12.00  1.75             2              0       100   NaN      NaN
# 13  12.00  1.75             2             10       100  23.0      NaN
# 14  12.00  1.75             3             10       100  24.0      NaN
# 15  12.00  1.75             2              4       100   NaN      NaN
# 16  12.00  1.75             2              4       100   NaN      NaN
# 17  12.00  1.75             2              5       100   NaN      NaN
# 18  13.00  2.00             1             10       100  23.0      NaN
# 19  13.00  2.00             1             10       100  25.0      NaN
# 20  13.00  2.00             1              9       100   NaN      NaN
# 21  13.00  2.00             1              9       100   NaN      NaN
# 22  13.00  2.00             1             10       100  26.0      NaN
# 23  13.00  2.00             1              2       100   NaN      8.9
# 24  16.00  2.00             3              4       100   NaN      8.9
# 25  15.00  2.00             3              4       100   NaN      8.9
# 26  13.00  2.00             1              2       100   NaN      8.9
# 27  13.00  2.00             1              2       100   NaN      8.9
# 28  13.00  2.00             1              5       100   NaN      8.9
# 29  13.00  2.00             1              6       100   NaN      8.8
# 30  13.00  2.00             4              1       100   NaN      8.7
# 31  14.00  2.00             5              1       100   NaN      8.7
# 32  14.00  3.00             3              4       100   NaN      8.7
# 33  12.00  3.00             3              3       100   NaN      8.7
# 34  20.00  3.00             4              6       100   NaN      8.7
# 35  20.00  3.50             3              4       100   NaN      8.7
# 36  18.00  3.00             3              7       100   NaN      8.7
# 37  18.00  3.00             5              6       100   NaN      9.2
# 38  18.00  3.50             3              4       100   NaN      9.2
# 39  16.00  3.50             1              2       100   NaN      9.2
# 40  16.00  2.50             2              7       100   NaN      9.2
# 41  16.00  2.50             2             10       100   NaN      9.1
# 42  16.00  2.50             2              7       100   NaN      8.9
# 43  16.00  2.65             1             10       100  16.0      8.9
# 44  16.00  2.60             2              7       100   NaN      8.9
# 45  16.00  2.50             2              7       100   NaN      8.9
# 46  14.00  2.50             1              4       100   NaN      8.9
# 47  18.00  2.50             3             10       100  14.0      8.9
# 48  18.00  2.50             3              8       100   NaN      8.9
# 49  18.00  2.65             3             10       100  14.0      8.9
#
#     Full Track        Date
# 0            1  05/20/2022
# 1            1  05/20/2022
# 2            1  05/20/2022
# 3            1  05/20/2022
# 4            1  05/20/2022
# 5            1  05/20/2022
# 6            1  05/20/2022
# 7            1  05/21/2022
# 8            1  05/21/2022
# 9            1  05/21/2022
# 10           1  05/21/2022
# 11           1   5/22/2022
# 12           1   5/22/2022
# 13           1   5/22/2022
# 14           1   5/22/2022
# 15           1   5/22/2022
# 16           1   5/22/2022
# 17           1   5/22/2022
# 18           1   5/22/2022
# 19           1   5/22/2022
# 20           1   5/22/2022
# 21           1   5/22/2022
# 22           1   5/22/2022
# 23           1   5/22/2022
# 24           1   5/22/2022
# 25           1   5/22/2022
# 26           1   5/22/2022
# 27           1   5/22/2022
# 28           1   5/22/2022
# 29           1   5/22/2022
# 30           1   5/25/2022
# 31           0   5/25/2022
# 32           0   5/25/2022
# 33           0   5/25/2022
# 34           0   5/25/2022
# 35           0   5/25/2022
# 36           0   5/25/2022
# 37           0   5/25/2022
# 38           0   5/25/2022
# 39           0   5/25/2022
# 40           0   5/25/2022
# 41           0   5/25/2022
# 42           0   5/25/2022
# 43           0   5/25/2022
# 44           0   5/25/2022
# 45           0   5/25/2022
# 46           0   5/25/2022
# 47           0   5/25/2022
# 48           0   5/25/2022
# 49           0   5/25/2022
